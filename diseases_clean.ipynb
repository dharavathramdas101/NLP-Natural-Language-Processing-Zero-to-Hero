# %% [markdown]
# <a href="https://colab.research.google.com/github/dharavathramdas101/NLP-Natural-Language-Processing-Zero-to-Hero/blob/main/diseases_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"/content/diseases_data (3).csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                           overview  \
# 0           0  related information covid19 cold allergies and...
# 1           1  a fever is a temporary rise in body temperatur...
# 2           2  a fever is a temporary rise in body temperatur...
# 3           3  cancer refers to any one of a large number of ...
# 4           4  acquired immunodeficiency syndrome aids is a c...
#
#                                             symptoms  \
# 0  might last longer in people who smoke most oft...
# 1  body temperatures vary slightly from person to...
# 2  body temperatures vary slightly from person to...
# 3  signs and symptoms caused by cancer will vary ...
# 4  the symptoms of hiv and aids vary depending on...
#
#                                               causes  \
# 0  many viruses can cause a common cold rhinoviru...
# 1  typical body temperature is a balance of heat ...
# 2  typical body temperature is a balance of heat ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'overview', 'symptoms', 'causes', 'complications',
#        'prevention', 'disease'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.columns
# Out:
# Index(['overview', 'symptoms', 'causes', 'complications', 'prevention',
#        'disease'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['overview', 'symptoms', 'causes', 'complications', 'prevention',
#        'disease'],
#       dtype='object')

# %%
df = df.rename(columns={"overview":"description"})

# %%
df.columns
# Out:
# Index(['description', 'symptoms', 'causes', 'complications', 'prevention',
#        'disease'],
#       dtype='object')

# %%
len(df['disease'])
# Out:
# 58

# %%
print(set(df['disease']))
# Out:
# {'botulism', 'flu', 'whooping-cough', 'pneumonia', 'dengue-fever', 'obesity', 'hepatitis-c', 'shingles', 'anxiety', 'mumps', 'kidney-failure', 'bronchitis', 'hepatitis-a', 'brain-aneurysm', 'tetanus', 'diphtheria', 'hpv-infection', 'chickenpox', 'diabetes', 'common-cold', 'stroke', 'chlamydia', 'encephalitis', 'rubella', 'malaria', 'polio', 'anemia', 'syphilis', 'asthma', 'heart-failure', 'copd', 'alzheimers-disease', 'sepsis', 'measles', 'hepatitis-b', 'hiv-aids', 'abdominal-aortic-aneurysm', 'lyme-disease', 'cancer', 'meningitis', 'depression', 'lung-cancer', 'gonorrhea', 'heart-disease', 'alcohol-poisoning', 'fever', 'emphysema'}

# %%
len(set(df['disease']))
# Out:
# 47

# %%
df[df['disease'].duplicated()]
# Out:
#                                           description  \
# 2   a fever is a temporary rise in body temperatur...
# 11  bronchitis is an inflammation of the lining of...
# 12  tuberculosis tb is a serious illness that main...
# 24  tetanus is a serious disease of the nervous sy...
# 26  diphtheria enlarge image close diphtheria diph...
# 41  meningitis is an infection and inflammation of...
# 42  encephalitis ensefuhlietis is inflammation of ...
# 45  acute respiratory distress syndrome ards occur...
# 51  acne is a skin condition that occurs when your...
# 54  what is depression a mayo clinic expert explai...
# 55  what is type 1 diabetes a mayo clinic expert e...
#
#                                              symptoms  \
# 2   body temperatures vary slightly from person to...
# 11  for either acute bronchitis or chronic bronchi...
# 12  when tb germs survive and multiply in the lung...
# 24  and complications until the effects of the tet...
# ...

# %%
df= df.drop_duplicates()

# %%
len(set(df['disease']))
# Out:
# 47

# %%
df.columns
# Out:
# Index(['description', 'symptoms', 'causes', 'complications', 'prevention',
#        'disease'],
#       dtype='object')

# %%
df['disease'][8]
# Out:
# 'pneumonia'

# %%
df.to_csv('clean_disease_data.csv')

# %%
print(df.loc[[6]]['causes'])
# Out:
# 6    obstructed airflow from the lungs symptoms inc...
# Name: causes, dtype: object

# %%
len(df.loc[[5]]['symptoms'])
# Out:
# 1

# %%
df.loc[[5]]['symptoms']
# Out:
# 5    lung cancer typically doesnt cause signs and s...
# Name: symptoms, dtype: object

# %%
df.columns
# Out:
# Index(['description', 'symptoms', 'causes', 'complications', 'prevention',
#        'disease'],
#       dtype='object')

# %%
df1 = df.iloc[:,0:5]

# %%
df1.head()
# Out:
#                                          description  \
# 0  related information covid19 cold allergies and...
# 1  a fever is a temporary rise in body temperatur...
# 3  cancer refers to any one of a large number of ...
# 4  acquired immunodeficiency syndrome aids is a c...
# 5  lung cancer enlarge image close lung cancer lu...
#
#                                             symptoms  \
# 0  might last longer in people who smoke most oft...
# 1  body temperatures vary slightly from person to...
# 3  signs and symptoms caused by cancer will vary ...
# 4  the symptoms of hiv and aids vary depending on...
# 5  lung cancer typically doesnt cause signs and s...
#
#                                               causes  \
# 0  many viruses can cause a common cold rhinoviru...
# 1  typical body temperature is a balance of heat ...
# 3  cancer is caused by changes mutations to the d...
# 4  hiv is caused by a virus it can spread through...
# ...

# %%
df1['description'].head()
# Out:
# 0    related information covid19 cold allergies and...
# 1    a fever is a temporary rise in body temperatur...
# 3    cancer refers to any one of a large number of ...
# 4    acquired immunodeficiency syndrome aids is a c...
# 5    lung cancer enlarge image close lung cancer lu...
# Name: description, dtype: object

# %%
len(df1['description'])
# Out:
# 50

# %%
df1 = df1.reset_index(drop=True)

# %%
df1['description'].head()
# Out:
# 0    related information covid19 cold allergies and...
# 1    a fever is a temporary rise in body temperatur...
# 2    cancer refers to any one of a large number of ...
# 3    acquired immunodeficiency syndrome aids is a c...
# 4    lung cancer enlarge image close lung cancer lu...
# Name: description, dtype: object

# %%
# 50

# %%
df1['description'][5]
# Out:
# 'chronic obstructive pulmonary disease copd is a chronic inflammatory lung disease that causes obstructed airflow from the lungs'

# %%
df2 = df.set_index('disease')

# %%
df2.head()
# Out:
#                                                    description  \
# disease
# common-cold  related information covid19 cold allergies and...
# fever        a fever is a temporary rise in body temperatur...
# cancer       cancer refers to any one of a large number of ...
# hiv-aids     acquired immunodeficiency syndrome aids is a c...
# lung-cancer  lung cancer enlarge image close lung cancer lu...
#
#                                                       symptoms  \
# disease
# common-cold  might last longer in people who smoke most oft...
# fever        body temperatures vary slightly from person to...
# cancer       signs and symptoms caused by cancer will vary ...
# hiv-aids     the symptoms of hiv and aids vary depending on...
# lung-cancer  lung cancer typically doesnt cause signs and s...
#
#                                                         causes  \
# disease
# common-cold  many viruses can cause a common cold rhinoviru...
# ...

# %%
df1['description'][4][:167]
# Out:
# 'lung cancer enlarge image close lung cancer lung cancer lung cancer begins in the cells of your lungs lung cancer is a type of cancer that begins in the lungs your lun'

# %%
df1['symptoms'][5][:167]
# Out:
# 'include breathing difficulty cough mucus sputum production and wheezing its typically caused by longterm exposure to irritating gases or particulate matter most often '

# %%
df.columns
# Out:
# Index(['description', 'symptoms', 'causes', 'complications', 'prevention',
#        'disease'],
#       dtype='object')

# %%
df1 = df.iloc[:,0:6]
df1 = df1.reset_index(drop=True)
df1.columns[1]
# Out:
# 'symptoms'

# %%
df1.head(5)
# Out:
#                                          description  \
# 0  related information covid19 cold allergies and...
# 1  a fever is a temporary rise in body temperatur...
# 2  cancer refers to any one of a large number of ...
# 3  acquired immunodeficiency syndrome aids is a c...
# 4  lung cancer enlarge image close lung cancer lu...
#
#                                             symptoms  \
# 0  might last longer in people who smoke most oft...
# 1  body temperatures vary slightly from person to...
# 2  signs and symptoms caused by cancer will vary ...
# 3  the symptoms of hiv and aids vary depending on...
# 4  lung cancer typically doesnt cause signs and s...
#
#                                               causes  \
# 0  many viruses can cause a common cold rhinoviru...
# 1  typical body temperature is a balance of heat ...
# 2  cancer is caused by changes mutations to the d...
# 3  hiv is caused by a virus it can spread through...
# ...

# %%
df1.tail()
# Out:
#                                           description  \
# 45  acne is a skin condition that occurs when your...
# 46  brain aneurysm enlarge image close brain aneur...
# 47  what is depression a mayo clinic expert explai...
# 48  heart failure occurs when the heart muscle doe...
# 49  obesity is a complex disease involving an exce...
#
#                                              symptoms  \
# 45  cystic acne enlarge image close cystic acne cy...
# 46  but screening can save lives click here for an...
# 47  that make up depression emotionally you may fe...
# 48  of heart failure and may help some people live...
# 49  body mass index bmi is often used to diagnose ...
#
#                                                causes  \
# 45  whiteheads blackheads or pimples acne is most ...
# 46  bleeding in the brain known as a hemorrhagic s...
# 47  feelings of sadness that wont go away unfortun...
# 48  fluid to build up in the lungs and in the legs...
# ...

# %%
df1.loc[0,'description']
# Out:
# 'related information covid19 cold allergies and the flu what are the differences related informationcovid19 cold allergies and the flu what are the differences the common cold is an illness affecting your nose and throat most often its harmless but it might not feel that way germs called viruses cause a common cold often adults may have two or three colds each year infants and young children may have colds more often most people recover from a common cold in 7 to 10 days'

# %%
df1['description'][0]
# Out:
# 'related information covid19 cold allergies and the flu what are the differences related informationcovid19 cold allergies and the flu what are the differences the common cold is an illness affecting your nose and throat most often its harmless but it might not feel that way germs called viruses cause a common cold often adults may have two or three colds each year infants and young children may have colds more often most people recover from a common cold in 7 to 10 days'

# %%
#for i in range(0,49):
    #df1['description'][0] = df1.loc[i,'description'][:171]

# %%
df1['description'][0]
# Out:
# 'related information covid19 cold allergies and the flu what are the differences related informationcovid19 cold allergies and the flu what are the differences the common cold is an illness affecting your nose and throat most often its harmless but it might not feel that way germs called viruses cause a common cold often adults may have two or three colds each year infants and young children may have colds more often most people recover from a common cold in 7 to 10 days'

# %%
df1.columns
# Out:
# Index(['description', 'symptoms', 'causes', 'complications', 'prevention',
#        'disease'],
#       dtype='object')

# %%
df4 = pd.DataFrame()

# %%
def clean_data(text):
    
    for i in range(0,49):
        df1[text][i] = df1.loc[i,text][:171]
  

clean_data('symptoms')

# %%
clean_data('causes')

# %%
clean_data('complications')

# %%
clean_data('prevention')

# %%
df1.loc[1,'causes']
# Out:
# 'typical body temperature is a balance of heat production and heat loss an area in the brain called the hypothalamus hipoethaluhmuhs also known as your bodys thermostat mon'

# %%
df1['causes'][1]
# Out:
# 'typical body temperature is a balance of heat production and heat loss an area in the brain called the hypothalamus hipoethaluhmuhs also known as your bodys thermostat mon'

# %%
df1['symptoms'][0]
# Out:
# 'might last longer in people who smoke most often you dont need medical care for a common cold if symptoms dont get better or if they get worse see your health care provide'

# %%
df1.head()
# Out:
#                                          description  \
# 0  related information covid19 cold allergies and...
# 1  a fever is a temporary rise in body temperatur...
# 2  cancer refers to any one of a large number of ...
# 3  acquired immunodeficiency syndrome aids is a c...
# 4  lung cancer enlarge image close lung cancer lu...
#
#                                             symptoms  \
# 0  might last longer in people who smoke most oft...
# 1  body temperatures vary slightly from person to...
# 2  signs and symptoms caused by cancer will vary ...
# 3  the symptoms of hiv and aids vary depending on...
# 4  lung cancer typically doesnt cause signs and s...
#
#                                               causes  \
# 0  many viruses can cause a common cold rhinoviru...
# 1  typical body temperature is a balance of heat ...
# 2  cancer is caused by changes mutations to the d...
# 3  hiv is caused by a virus it can spread through...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   description    50 non-null     object
#  1   symptoms       50 non-null     object
#  2   causes         50 non-null     object
#  3   complications  50 non-null     object
#  4   prevention     50 non-null     object
#  5   disease        50 non-null     object
# dtypes: object(6)
# memory usage: 2.5+ KB

# %%
df1
# Out:
#                                           description  \
# 0   related information covid19 cold allergies and...
# 1   a fever is a temporary rise in body temperatur...
# 2   cancer refers to any one of a large number of ...
# 3   acquired immunodeficiency syndrome aids is a c...
# 4   lung cancer enlarge image close lung cancer lu...
# 5   chronic obstructive pulmonary disease copd is ...
# 6   asthma attack enlarge image close asthma attac...
# 7   pneumonia and your lungs enlarge image close p...
# 8   emphysema enlarge image close emphysema emphys...
# 9   bronchitis is an inflammation of the lining of...
# 10  tuberculosis tb is a serious illness that main...
# 11  heart disease describes a range of conditions ...
# 12  what is a stroke a mayo clinic expert explains...
# 13  what is type 1 diabetes a mayo clinic expert e...
# 14  flu influenza is an infection of the nose thro...
# 15  sepsis is a serious condition in which the bod...
# ...

# %%
df1['description'][12]
# Out:
# 'what is a stroke a mayo clinic expert explains learn more from neurologist robert brown md show transcript for video what is a stroke a mayo clinic expert explains im dr robert brown neurologist at mayo clinic in this video well cover the basics of a stroke what is it who it happens to the'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 57
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   description    50 non-null     object
#  1   symptoms       50 non-null     object
#  2   causes         50 non-null     object
#  3   complications  50 non-null     object
#  4   prevention     50 non-null     object
#  5   disease        50 non-null     object
# dtypes: object(6)
# memory usage: 4.8+ KB

# %%
df1.to_csv("clean_diseases_data2.csv")

# %%
df5 = pd.read_csv(r"/content/clean_diseases_data2.csv")

# %%
df5
# Out:
#     Unnamed: 0                                        description  \
# 0            0  related information covid19 cold allergies and...
# 1            1  a fever is a temporary rise in body temperatur...
# 2            2  cancer refers to any one of a large number of ...
# 3            3  acquired immunodeficiency syndrome aids is a c...
# 4            4  lung cancer enlarge image close lung cancer lu...
# 5            5  chronic obstructive pulmonary disease copd is ...
# 6            6  asthma attack enlarge image close asthma attac...
# 7            7  pneumonia and your lungs enlarge image close p...
# 8            8  emphysema enlarge image close emphysema emphys...
# 9            9  bronchitis is an inflammation of the lining of...
# 10          10  tuberculosis tb is a serious illness that main...
# 11          11  heart disease describes a range of conditions ...
# 12          12  what is a stroke a mayo clinic expert explains...
# ...

# %%
df5.head()
# Out:
#    Unnamed: 0                                        description  \
# 0           0  related information covid19 cold allergies and...
# 1           1  a fever is a temporary rise in body temperatur...
# 2           2  cancer refers to any one of a large number of ...
# 3           3  acquired immunodeficiency syndrome aids is a c...
# 4           4  lung cancer enlarge image close lung cancer lu...
#
#                                             symptoms  \
# 0  might last longer in people who smoke most oft...
# 1  body temperatures vary slightly from person to...
# 2  signs and symptoms caused by cancer will vary ...
# 3  the symptoms of hiv and aids vary depending on...
# 4  lung cancer typically doesnt cause signs and s...
#
#                                               causes  \
# 0  many viruses can cause a common cold rhinoviru...
# 1  typical body temperature is a balance of heat ...
# 2  cancer is caused by changes mutations to the d...
# ...

# %%
df5 = df5.drop('Unnamed: 0',axis=1)

# %%
df5 = df5.drop(['causes','complications'],axis=1)

# %%
df5.head()
# Out:
#                                          description  \
# 0  related information covid19 cold allergies and...
# 1  a fever is a temporary rise in body temperatur...
# 2  cancer refers to any one of a large number of ...
# 3  acquired immunodeficiency syndrome aids is a c...
# 4  lung cancer enlarge image close lung cancer lu...
#
#                                             symptoms  \
# 0  might last longer in people who smoke most oft...
# 1  body temperatures vary slightly from person to...
# 2  signs and symptoms caused by cancer will vary ...
# 3  the symptoms of hiv and aids vary depending on...
# 4  lung cancer typically doesnt cause signs and s...
#
#                                           prevention      disease
# 0  theres no vaccine for the common cold you can ...  common-cold
# 1  you may be able to prevent fevers by reducing ...        fever
# 2  products servicesassortment of pill aids from ...       cancer
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   description  50 non-null     object
#  1   symptoms     50 non-null     object
#  2   prevention   50 non-null     object
#  3   disease      50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
df5.to_csv("disease.csv")

# %%
df6 = pd.read_csv(r"/content/disease.csv")

# %%
df6
# Out:
#     Unnamed: 0                                        description  \
# 0            0  related information covid19 cold allergies and...
# 1            1  a fever is a temporary rise in body temperatur...
# 2            2  cancer refers to any one of a large number of ...
# 3            3  acquired immunodeficiency syndrome aids is a c...
# 4            4  lung cancer enlarge image close lung cancer lu...
# 5            5  chronic obstructive pulmonary disease copd is ...
# 6            6  asthma attack enlarge image close asthma attac...
# 7            7  pneumonia and your lungs enlarge image close p...
# 8            8  emphysema enlarge image close emphysema emphys...
# 9            9  bronchitis is an inflammation of the lining of...
# 10          10  tuberculosis tb is a serious illness that main...
# 11          11  heart disease describes a range of conditions ...
# 12          12  what is a stroke a mayo clinic expert explains...
# ...
