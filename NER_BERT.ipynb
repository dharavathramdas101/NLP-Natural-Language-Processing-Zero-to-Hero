# %% [markdown]
# <a href="https://colab.research.google.com/github/dharavathramdas101/NLP-Natural-Language-Processing-Zero-to-Hero/blob/main/NER_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NER --> Name Entity Recognization
# find entitiees such a person, location, organization, so on
#
# ## Token Classification
#
# bil gates is a founder of microsoft
#
# [ramdas]    [gates]   [is]    [a]    [founder]   [of] [ microsoft]
# person     person       obj   obj  designation obj  organization
#
# classifying each token wise
#
# ## POS
# POS --> parts of speech tagging: --> make each word in a sentence as corresponding toa particuler to aparts of speech(such as  noun, verb, adjective)
#
# ## chunking
# collect same entity
#
# ramdas gates is the founder of microsoft
# per per obj obj desig obj organizat
#
# ramdas gates are similar entity so i combain both
# as
# ramdas gates
#   person
#
#
# we use token classification and ner tages
#
# ## how ner tages creted??
#
# ramdas gates is the founder of microsoft
#
# ### 1 Step:
# token
# [[ramdas], [gates], [is] , [the], [founder], [of], [microsoft]]
#
# stopwords not required
#
#
# ### 2 Step:
# integer encoding
# [[1],[2],[3],[4],[5],[6],[7]]
# unique numbers
#
#
# -> O object
# -> B.PER /I.PER  (begining person/  inside of sentence
# ramdas /gates
# B.PER / I.PER
# ->B.ORG/I.ORG  (ORGANIZATION)
# ->B.LOC/I.LOC (LOCATION)
# -> B.MISE/I. MISE  (MISCELLANEOUS ENTITY
#
# O, BPER,   ....
#  TOTAL 9 ENTITY'S

# %%
# !pip install transformers datasets tokenizers seqeval -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 88.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 41.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 110.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 30.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 27.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 74.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.7 MB/s eta 0:00:00
# ...

# %%
import datasets
import numpy as np
from transformers import BertTokenizerFast       # tokenizer
from transformers import DataCollatorForTokenClassification   # it applu augmentation on data
from transformers import AutoModelForTokenClassification   # model

# %% [markdown]
# ## donload dataset

# %%
conll2003 = datasets.load_dataset("conll2003")
# Out:
# ...
# Generating test split:   0%|          | 0/3453 [00:00<?, ? examples/s]
# Dataset conll2003 downloaded and prepared to /root/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
conll2003
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 14041
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3250
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3453
#     })
# })

# %%
conll2003['train']
# Out:
# Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 14041
# })

# %%
conll2003['train'][0]
# Out:
# {'id': '0',
#  'tokens': ['EU',
#   'rejects',
#   'German',
#   'call',
#   'to',
#   'boycott',
#   'British',
#   'lamb',
#   '.'],
#  'pos_tags': [22, 42, 16, 21, 35, 37, 16, 21, 7],
#  'chunk_tags': [11, 21, 11, 12, 21, 22, 11, 12, 0],
#  'ner_tags': [3, 0, 7, 0, 0, 0, 7, 0, 0]}

# %%
conll2003['test'][2]
# Out:
# {'id': '2',
#  'tokens': ['AL-AIN', ',', 'United', 'Arab', 'Emirates', '1996-12-06'],
#  'pos_tags': [22, 6, 22, 22, 23, 11],
#  'chunk_tags': [11, 0, 11, 12, 12, 12],
#  'ner_tags': [5, 0, 5, 6, 6, 0]}

# %%
conll2003['train'].features['ner_tags']
# Out:
# Sequence(feature=ClassLabel(names=['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC'], id=None), length=-1, id=None)

# %%
conll2003['train'].description
# Out:
# 'The shared task of CoNLL-2003 concerns language-independent named entity recognition. We will concentrate on\nfour types of named entities: persons, locations, organizations and names of miscellaneous entities that do\nnot belong to the previous three groups.\n\nThe CoNLL-2003 shared task data files contain four columns separated by a single space. Each word has been put on\na separate line and there is an empty line after each sentence. The first item on each line is a word, the second\na part-of-speech (POS) tag, the third a syntactic chunk tag and the fourth the named entity tag. The chunk tags\nand the named entity tags have the format I-TYPE which means that the word is inside a phrase of type TYPE. Only\nif two phrases of the same type immediately follow each other, the first word of the second phrase will have tag\nB-TYPE to show that it starts a new phrase. A word with tag O is not part of a phrase. Note the dataset uses IOB2\ntagging scheme, whereas the original dataset use
# ...

# %% [markdown]
# ## tokenizer pre trained

# %%
tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")

# %%
conll2003['train'][0]
# Out:
# {'id': '0',
#  'tokens': ['EU',
#   'rejects',
#   'German',
#   'call',
#   'to',
#   'boycott',
#   'British',
#   'lamb',
#   '.'],
#  'pos_tags': [22, 42, 16, 21, 35, 37, 16, 21, 7],
#  'chunk_tags': [11, 21, 11, 12, 21, 22, 11, 12, 0],
#  'ner_tags': [3, 0, 7, 0, 0, 0, 7, 0, 0]}
